# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Equipo\\00Test'

# %%
import chardet
with open("Dataset/sleeping-alone-data.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
pd.read_csv("Dataset/sleeping-alone-data.csv" , encoding ='ISO-8859-1', sep = ',',index_col = None )
df = pd.read_csv("Dataset/sleeping-alone-data.csv" , encoding ='ISO-8859-1', sep = ',',index_col = None )
df
# Out:
#           StartDate        EndDate  \
# 0               NaN            NaN
# 1     7/10/14 18:37  7/10/14 18:39
# 2     7/10/14 15:54  7/10/14 15:56
# 3     7/10/14 15:44  7/10/14 15:49
# 4     7/10/14 13:47  7/10/14 13:47
# ...             ...            ...
# 1089   7/9/14 17:46   7/9/14 17:49
# 1090   7/9/14 17:46   7/9/14 17:49
# 1091   7/9/14 17:46   7/9/14 17:47
# 1092   7/9/14 17:45   7/9/14 17:46
# 1093   7/9/14 17:45   7/9/14 17:46
#
#      Which of the following best describes your current relationship status?  \
# 0                                              Response
# 1       Single, but cohabiting with a significant other
# 2       Single, but cohabiting with a significant other
# 3                                               Married
# 4                                               Married
# ...                                                 ...
# 1089                                            Married
# 1090                                            Married
# ...

# %%
df.dtypes
# Out:
# StartDate                                                                                                                                              object
# EndDate                                                                                                                                                object
# Which of the following best describes your current relationship status?                                                                                object
# How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship.    object
# When both you and your partner are at home, how often do you sleep in separate beds?                                                                   object
# When you're not sleeping in the same bed as your partner, where do you typically sleep?                                                                object
# ...

# %%
df.Gender.hist()

# %%
df.head()
# Out:
#        StartDate        EndDate  \
# 0            NaN            NaN
# 1  7/10/14 18:37  7/10/14 18:39
# 2  7/10/14 15:54  7/10/14 15:56
# 3  7/10/14 15:44  7/10/14 15:49
# 4  7/10/14 13:47  7/10/14 13:47
#
#   Which of the following best describes your current relationship status?  \
# 0                                           Response
# 1    Single, but cohabiting with a significant other
# 2    Single, but cohabiting with a significant other
# 3                                            Married
# 4                                            Married
#
#   How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship.  \
# 0                                           Response
# 1                                          1-5 years
# 2                                          1-5 years
# 3                                          1-5 years
# 4                                          1-5 years
#
# ...

# %%
df_lleno_0 = df.fillna(0)
df_lleno_0.head()
# Out:
#       Start_Date       End_Date  \
# 0              0              0
# 1  7/10/14 18:37  7/10/14 18:39
# 2  7/10/14 15:54  7/10/14 15:56
# 3  7/10/14 15:44  7/10/14 15:49
# 4  7/10/14 13:47  7/10/14 13:47
#
#                                Relationship_Status Relationship_Years  \
# 0                                         Response           Response
# 1  Single, but cohabiting with a significant other          1-5 years
# 2  Single, but cohabiting with a significant other          1-5 years
# 3                                          Married          1-5 years
# 4                                          Married          1-5 years
#
#     Often_Sleep_Separate                                    Where_You_Sleep  \
# 0               Response                                           Response
# 1    Once a year or less                                 On the couch/chair
# 2  A few times per month  I sleep in our shared bed, my partner is the o...
# ...

# %%
df.rename(columns = {'StartDate': "Start_Date", 
                     'EndDate': "End_Date",
                    'Which of the following best describes your current relationship status?':"Relationship_Status",
       'How long have you been in your current relationship? If you are not currently in a relationship, please answer according to your last relationship.': "Relationship_Years"}, inplace =True)

# %%
df.columns
# Out:
# Index(['Start_Date', 'End_Date', 'Relationship_Status', 'Relationship_Years',
#        'Often_Sleep_Separate', 'Where_You_Sleep', 'Unnamed:_6',
#        'When_you're_not_sleeping_in_the_same_bed,_where_does_your_partner_typically_sleep?',
#        'Unnamed:_8', 'Reasons', 'Unnamed:_10', 'Unnamed:_11', 'Unnamed:_12',
#        'Unnamed:_13', 'Unnamed:_14', 'Unnamed:_15', 'Unnamed:_16',
#        'Unnamed:_17', 'Unnamed:_18', 'Unnamed:_19', 'Firs_Time',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"sleeping_in_separate_beds_helps_us_to_stay_together."',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"we_sleep_better_when_we_sleep_in_separate_beds."',
#        'To_what_extent_do_you_agree_with_the_following_statement:ë_"our_sex_life_has_improved_as_a_result_of_sleeping_in_separate_beds."ë_',
#        'Ocupation', 'Unnamed:_25', 'Gender', 'Age', 'Household_Income',
#        'Education', 'Location_(Census_Region)', 'Total_zb'],
# ...

# %%
df.rename(columns = {'When both you and your partner are at home, how often do you sleep in separate beds?': "Often_Sleep_Separate",
                    "When you/'re not sleeping in the same bed as your partner, where do you typically sleep?": "Where_You_Sleep",
                     "When you/'re not sleeping in the same bed, where does your partner typically sleep?": "Where_Your_Partner_Sleep",
                     "What are the reasons that you sleep in separate beds? Please select all that apply." : "Reasons",
                     'When was the first time you slept in separate beds?' : "First_Time",
                     'To what extent do you agree with the following statement: /"sleeping in separate beds helps us to stay together./" ' : "Option_Help_Us",
                     'To what extent do you agree with the following statement: /"we sleep better when we sleep in separate beds./" ' : "Option_Sleep_Better",
                     'To what extent do you agree with the following statement:ë_/"our sex life has improved as a result of sleeping in separate beds./"ë_' : "Option_Sex_Improve",                  
                     'Which of the following best describes your current occupation?': "Ocupation",
                    }, inplace=True)

# %%
df.columns
# Out:
# Index(['Start_Date', 'End_Date', 'Relationship_Status', 'Relationship_Years',
#        'Often_Sleep_Separate', 'Where_You_Sleep', 'Unnamed:_6',
#        'When_you're_not_sleeping_in_the_same_bed,_where_does_your_partner_typically_sleep?',
#        'Unnamed:_8', 'Reasons', 'Unnamed:_10', 'Unnamed:_11', 'Unnamed:_12',
#        'Unnamed:_13', 'Unnamed:_14', 'Unnamed:_15', 'Unnamed:_16',
#        'Unnamed:_17', 'Unnamed:_18', 'Unnamed:_19', 'Firs_Time',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"sleeping_in_separate_beds_helps_us_to_stay_together."',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"we_sleep_better_when_we_sleep_in_separate_beds."',
#        'To_what_extent_do_you_agree_with_the_following_statement:ë_"our_sex_life_has_improved_as_a_result_of_sleeping_in_separate_beds."ë_',
#        'Ocupation', 'Unnamed:_25', 'Gender', 'Age', 'Household_Income',
#        'Education', 'Location_(Census_Region)', 'Total_zb'],
# ...

# %%
df.rename(columns = {'When_you/'re_not_sleeping_in_the_same_bed,_where_does_your_partner_typically_sleep?': "Where_Your_Partnet_Sleep",
                     'To what extent do you agree with the following statement/: /"sleeping in separate beds helps us to stay together./" ' : "Option_Help_Us",
                     'To what extent do you agree with the following statement/: /"we sleep better when we sleep in separate beds./" ' : "Option_Sleep_Better",
                     'To what extent do you agree with the following statement/:ë_/"our sex life has improved as a result of sleeping in separate beds./"ë_' : "Option_Sex_Improve",                  
                     
                    }, inplace=True)
# Out:
#   File "<ipython-input-141-efd9181d0a40>", line 1
#     df.rename(columns = {'When_you/'re_not_sleeping_in_the_same_bed,_where_does_your_partner_typically_sleep?': "Where_Your_Partnet_Sleep",
#                                                                   ^
# SyntaxError: invalid syntax

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['Start_Date', 'End_Date', 'Relationship_Status', 'Relationship_Years',
#        'Often_Sleep_Separate', 'Where_You_Sleep', 'Unnamed:_6',
#        'When_you're_not_sleeping_in_the_same_bed,_where_does_your_partner_typically_sleep?',
#        'Unnamed:_8', 'Reasons', 'Unnamed:_10', 'Unnamed:_11', 'Unnamed:_12',
#        'Unnamed:_13', 'Unnamed:_14', 'Unnamed:_15', 'Unnamed:_16',
#        'Unnamed:_17', 'Unnamed:_18', 'Unnamed:_19', 'Firs_Time',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"sleeping_in_separate_beds_helps_us_to_stay_together."',
#        'To_what_extent_do_you_agree_with_the_following_statement:_"we_sleep_better_when_we_sleep_in_separate_beds."',
#        'To_what_extent_do_you_agree_with_the_following_statement:ë_"our_sex_life_has_improved_as_a_result_of_sleeping_in_separate_beds."ë_',
#        'Ocupation', 'Unnamed:_25', 'Gender', 'Age', 'Household_Income',
#        'Education', 'Location_(Census_Region)', 'Total_zb'],
# ...

# %%
df
# Out:
#          Start_Date       End_Date  \
# 0               NaN            NaN
# 1     7/10/14 18:37  7/10/14 18:39
# 2     7/10/14 15:54  7/10/14 15:56
# 3     7/10/14 15:44  7/10/14 15:49
# 4     7/10/14 13:47  7/10/14 13:47
# ...             ...            ...
# 1089   7/9/14 17:46   7/9/14 17:49
# 1090   7/9/14 17:46   7/9/14 17:49
# 1091   7/9/14 17:46   7/9/14 17:47
# 1092   7/9/14 17:45   7/9/14 17:46
# 1093   7/9/14 17:45   7/9/14 17:46
#
#                                   Relationship_Status  Relationship_Years  \
# 0                                            Response            Response
# 1     Single, but cohabiting with a significant other           1-5 years
# 2     Single, but cohabiting with a significant other           1-5 years
# 3                                             Married           1-5 years
# 4                                             Married           1-5 years
# ...                                               ...                 ...
# ...

# %%
df.Relationship_Status.value_counts()
# Out:
# Married                                            884
# Single, but cohabiting with a significant other    138
# In a domestic partnership or civil union            48
# Divorced                                            12
# Separated                                            8
# Widowed                                              3
# Response                                             1
# Name: Relationship_Status, dtype: int64

# %%
df.Often_Sleep_Separate.value_counts()
# Out:
# Never                    586
# Every night              147
# Once a year or less      137
# Once a month or less     101
# A few times per month     62
# A few times per week      46
# Response                   1
# Name: Often_Sleep_Separate, dtype: int64

# %%
df.Reasons.value_counts()
# Out:
# One of us snores    221
# Name: Reasons, dtype: int64

# %%
df.Relationship_Years.value_counts()
# Out:
# More than 20 years    468
# 6-10 years            165
# 1-5 years             162
# 11-15 years           159
# 16-20 years           104
# Less than 1 year       21
# Response                1
# Name: Relationship_Years, dtype: int64

# %%
df.sort_values(["Relationship_Years", "Age"], ascending = True)
# Out:
#          Start_Date       End_Date  \
# 1     7/10/14 18:37  7/10/14 18:39
# 2     7/10/14 15:54  7/10/14 15:56
# 3     7/10/14 15:44  7/10/14 15:49
# 4     7/10/14 13:47  7/10/14 13:47
# 5     7/10/14 13:13  7/10/14 13:14
# ...             ...            ...
# 723    7/9/14 18:40   7/9/14 18:40
# 748    7/9/14 18:37   7/9/14 18:37
# 788    7/9/14 18:33   7/9/14 18:33
# 962    7/9/14 18:01   7/9/14 18:06
# 1032   7/9/14 17:55   7/9/14 17:56
#
#                                   Relationship_Status Relationship_Years  \
# 1     Single, but cohabiting with a significant other          1-5 years
# 2     Single, but cohabiting with a significant other          1-5 years
# 3                                             Married          1-5 years
# 4                                             Married          1-5 years
# 5                                             Married          1-5 years
# ...                                               ...                ...
# ...

# %%
df.head(5)
# Out:
#       Start_Date       End_Date  \
# 0            NaN            NaN
# 1  7/10/14 18:37  7/10/14 18:39
# 2  7/10/14 15:54  7/10/14 15:56
# 3  7/10/14 15:44  7/10/14 15:49
# 4  7/10/14 13:47  7/10/14 13:47
#
#                                Relationship_Status Relationship_Years  \
# 0                                         Response           Response
# 1  Single, but cohabiting with a significant other          1-5 years
# 2  Single, but cohabiting with a significant other          1-5 years
# 3                                          Married          1-5 years
# 4                                          Married          1-5 years
#
#     Often_Sleep_Separate                                    Where_You_Sleep  \
# 0               Response                                           Response
# 1    Once a year or less                                 On the couch/chair
# 2  A few times per month  I sleep in our shared bed, my partner is the o...
# ...

# %%
df["Total_zb"] = df["Relationship_Status"] + df["Gender"] + df["Age"]
df.head(5)
# Out:
#       Start_Date       End_Date  \
# 0            NaN            NaN
# 1  7/10/14 18:37  7/10/14 18:39
# 2  7/10/14 15:54  7/10/14 15:56
# 3  7/10/14 15:44  7/10/14 15:49
# 4  7/10/14 13:47  7/10/14 13:47
#
#                                Relationship_Status Relationship_Years  \
# 0                                         Response           Response
# 1  Single, but cohabiting with a significant other          1-5 years
# 2  Single, but cohabiting with a significant other          1-5 years
# 3                                          Married          1-5 years
# 4                                          Married          1-5 years
#
#     Often_Sleep_Separate                                    Where_You_Sleep  \
# 0               Response                                           Response
# 1    Once a year or less                                 On the couch/chair
# 2  A few times per month  I sleep in our shared bed, my partner is the o...
# ...

# %%
df_lleno_0 = df.fillna(0)
df_lleno_0.head()
# Out:
#       Start_Date       End_Date  \
# 0              0              0
# 1  7/10/14 18:37  7/10/14 18:39
# 2  7/10/14 15:54  7/10/14 15:56
# 3  7/10/14 15:44  7/10/14 15:49
# 4  7/10/14 13:47  7/10/14 13:47
#
#                                Relationship_Status Relationship_Years  \
# 0                                         Response           Response
# 1  Single, but cohabiting with a significant other          1-5 years
# 2  Single, but cohabiting with a significant other          1-5 years
# 3                                          Married          1-5 years
# 4                                          Married          1-5 years
#
#     Often_Sleep_Separate                                    Where_You_Sleep  \
# 0               Response                                           Response
# 1    Once a year or less                                 On the couch/chair
# 2  A few times per month  I sleep in our shared bed, my partner is the o...
# ...

# %%
df = df.drop(columns=[ 'To_what_extent_do_you_agree_with_the_following_statement:ë_/"our_sex_life_has_improved_as_a_result_of_sleeping_in_separate_beds./"ë_' ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-cdb218a5e55f> in <module>
# ----> 1 df = df.drop(columns=[ 'To_what_extent_do_you_agree_with_the_following_statement:ë_/"our_sex_life_has_improved_as_a_result_of_sleeping_in_separate_beds./"ë_' ])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...
